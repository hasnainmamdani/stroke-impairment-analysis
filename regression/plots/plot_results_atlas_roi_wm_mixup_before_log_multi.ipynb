# %%
import numpy as np
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_colwidth", 200)
pd.set_option("display.max_row", 500)

# %%
def plot_scores(score_df, metric, score_type, title="", save_folder="", col_order=None, hue_order=None):

    g = sns.catplot(x="Domain", y="Score", hue="alpha", col="Data mul factor", col_order=col_order,
                    data=score_df, ci="sd", kind="bar", hue_order=hue_order,
                    row_order=[100.0, 80.0, 60.0, 40.0, 20.0])

    g.set_axis_labels("", "Score (Mean and Standard Deviation across 5 CV folds)")

    for i, ax in enumerate(g.fig.axes):
        ax.set_xticklabels(ax.get_xticklabels(), rotation=65)
        ax.axhline(0, color="black")

    g.fig.suptitle(title, y=1.08, fontsize=30)
    
    if metric == "R2" and score_type == "Out-of-sample":
        g.set(ylim=(-1, 0.2))
#         plt.savefig(save_folder + title, bbox_inches="tight")
#         pass
        
    if metric == "R2" and (score_type == "In-sample" or score_type == "In-sample (original)"):
        g.set(ylim=(-0.05, 1.0))
        for i, ax in enumerate(g.fig.axes):
            ax.axhline(0.1, color="black")
            ax.axhline(0.2, color="black")
        
    if metric == "MAE":
        g.set(ylim=(0.0, 1.6))
        for i, ax in enumerate(g.fig.axes):
            ax.axhline(0.6, color="black")
        
#     plt.show()
    plt.savefig(save_folder + title, bbox_inches="tight")


def plot_all_scores(score_df, title_prefix="", save_folder="", col_order=None, hue_order=None):   

    for metric in score_df["Metric"].unique():

        for score_type in np.sort(score_df["Score type"].unique()):
            
            for model in score_df["Model"].unique():

                filtered_data = score_df[(score_df["Metric"] == metric) & (score_df["Score type"] == score_type) 
                                         & (score_df["Model"] == model)]
                
                if score_type == "In-sample (original)":
                    filtered_data = filtered_data[filtered_data["alpha"] != "No mixup"]
                    col_order_new=["5x", "10x"]
                else:
                    col_order_new = col_order

                title = title_prefix + model + " - " + metric + " - " + score_type

                plot_scores(filtered_data, metric, score_type, title, save_folder, col_order=col_order_new, hue_order=hue_order)

# %%
# utility to load results
def load_dfs(direc, regex):
    path = "/Users/hasnainmamdani/Academics/McGill/thesis/stroke-impairment-analysis/regression/mixup/results_remote/" + direc
    filenames = glob.glob(os.path.join(path, regex))
    filenames.sort()

    res = []
    bps = []
    for fn in filenames:
        if "best-params-" in fn:
            bp = pd.read_hdf(fn, key='p', mode='r')
#             print(bp["% Data (train)"].unique(), bp["Data mul factor"].unique(), bp["alpha"].unique())
            print(bp["Data mul factor"].unique(), bp["alpha"].unique())
            bps.append(bp)
        else:
            res.append(pd.read_hdf(fn, key='p', mode='r'))

    print(len(res), len(bps))
    return res, bps

# %% [markdown]
# ## 1- Multiitask Ridge

# %%
# mridge = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_mridge_all.h5', key='p', mode='r')
# mbpridge = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_mridge_all.h5', key='p', mode='r')

mridge.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_mridge_all.h5', key='p', mode='w')
mbpridge.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_mridge_all.h5', key='p', mode='w')

# %%
mridlist, mbpridlist = load_dfs("", "*multioutput*mridge*")
# Out:
# ['No mixup' '5x' '10x'] ['No mixup' 0.01 0.1]
# ['5x' '10x'] [0.3 1. ]
# 2 2

# %%
# mbpridge

# %%
mridge = pd.concat(mridlist, ignore_index=True)
mbpridge = pd.concat(mbpridlist, ignore_index=True)

# %%
plot_all_scores(mridge, col_order=["No mixup", "5x", "10x"], hue_order=["No mixup", 0.01, 0.1, 0.3, 1.0])

# %% [markdown]
# ## 2- PLS

# %%
pls = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_pls_all.h5', key='p', mode='r')
bppls = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_pls_all.h5', key='p', mode='r')

# pls.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_pls_all.h5', key='p', mode='w')
# bppls.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_pls_all.h5', key='p', mode='w')

# %%
plslist, bpplslist = load_dfs("", "*multioutput*pls*")
# Out:
# ['No mixup' '5x' '10x'] ['No mixup' 0.01 0.1 0.3 1.0]
# 1 1

# %%
pls = pd.concat(plslist, ignore_index=True)
bppls = pd.concat(bpplslist, ignore_index=True)

# %%
bppls
# Out:
#    Data mul factor     alpha Model  Fold          Best params
# 0         No mixup  No mixup   PLS     1  {'n_components': 2}
# 1         No mixup  No mixup   PLS     2  {'n_components': 1}
# 2         No mixup  No mixup   PLS     3  {'n_components': 2}
# 3         No mixup  No mixup   PLS     4  {'n_components': 1}
# 4         No mixup  No mixup   PLS     5  {'n_components': 1}
# 5               5x      0.01   PLS     1  {'n_components': 6}
# 6               5x      0.01   PLS     2  {'n_components': 6}
# 7               5x      0.01   PLS     3  {'n_components': 6}
# 8               5x      0.01   PLS     4  {'n_components': 6}
# 9               5x      0.01   PLS     5  {'n_components': 6}
# 10              5x       0.1   PLS     1  {'n_components': 6}
# 11              5x       0.1   PLS     2  {'n_components': 6}
# 12              5x       0.1   PLS     3  {'n_components': 6}
# 13              5x       0.1   PLS     4  {'n_components': 6}
# 14              5x       0.1   PLS     5  {'n_components': 6}
# 15              5x       0.3   PLS     1  {'n_components': 6}
# 16              5x       0.3   PLS     2  {'n_components': 6}
# 17              5x       0.3   PLS     3  {'n_components': 6}
# 18              5x       0.3   PLS     4  {'n_components': 6}
# 19              5x       0.3   PLS     5  {'n_components': 6}
# 20              5x         1   PLS     1  {'n_components': 6}
# 21              5x         1   PLS     2  {'n_components': 6}
# 22              5x         1   PLS     3  {'n_components': 6}
# 23              5x         1   PLS     4  {'n_components': 6}
# 24              5x         1   PLS     5  {'n_components': 6}
# 25             10x      0.01   PLS     1  {'n_components': 6}
# 26             10x      0.01   PLS     2  {'n_components': 6}
# 27             10x      0.01   PLS     3  {'n_components': 6}
# 28             10x      0.01   PLS     4  {'n_components': 6}
# 29             10x      0.01   PLS     5  {'n_components': 6}
# 30             10x       0.1   PLS     1  {'n_components': 6}
# 31             10x       0.1   PLS     2  {'n_components': 6}
# 32             10x       0.1   PLS     3  {'n_components': 6}
# 33             10x       0.1   PLS     4  {'n_components': 6}
# 34             10x       0.1   PLS     5  {'n_components': 6}
# 35             10x       0.3   PLS     1  {'n_components': 6}
# 36             10x       0.3   PLS     2  {'n_components': 6}
# 37             10x       0.3   PLS     3  {'n_components': 6}
# 38             10x       0.3   PLS     4  {'n_components': 6}
# 39             10x       0.3   PLS     5  {'n_components': 6}
# 40             10x         1   PLS     1  {'n_components': 6}
# 41             10x         1   PLS     2  {'n_components': 6}
# 42             10x         1   PLS     3  {'n_components': 6}
# 43             10x         1   PLS     4  {'n_components': 6}
# 44             10x         1   PLS     5  {'n_components': 6}

# %%
plot_all_scores(pls, col_order=["No mixup", "5x", "10x"], hue_order=["No mixup", 0.01, 0.1, 0.3, 1.0])

# %% [markdown]
# ## 3- CCA

# %%
cca = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_cca_all.h5', key='p', mode='r')
bpcca = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_cca_all.h5', key='p', mode='r')

# cca.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_cca_all.h5', key='p', mode='w')
# bpcca.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_cca_all.h5', key='p', mode='w')

# %%
ccalist, bpccalist = load_dfs("", "*multioutput*cca*")
# Out:
# ['No mixup' '5x' '10x'] ['No mixup' 0.01 0.1 0.3 1.0]
# 1 1

# %%
bpcca
# Out:
#    Data mul factor     alpha Model  Fold          Best params
# 0         No mixup  No mixup   CCA     1  {'n_components': 1}
# 1         No mixup  No mixup   CCA     2  {'n_components': 1}
# 2         No mixup  No mixup   CCA     3  {'n_components': 1}
# 3         No mixup  No mixup   CCA     4  {'n_components': 1}
# 4         No mixup  No mixup   CCA     5  {'n_components': 1}
# 5               5x      0.01   CCA     1  {'n_components': 6}
# 6               5x      0.01   CCA     2  {'n_components': 6}
# 7               5x      0.01   CCA     3  {'n_components': 6}
# 8               5x      0.01   CCA     4  {'n_components': 6}
# 9               5x      0.01   CCA     5  {'n_components': 6}
# 10              5x       0.1   CCA     1  {'n_components': 6}
# 11              5x       0.1   CCA     2  {'n_components': 6}
# 12              5x       0.1   CCA     3  {'n_components': 6}
# 13              5x       0.1   CCA     4  {'n_components': 6}
# 14              5x       0.1   CCA     5  {'n_components': 6}
# 15              5x       0.3   CCA     1  {'n_components': 6}
# 16              5x       0.3   CCA     2  {'n_components': 6}
# 17              5x       0.3   CCA     3  {'n_components': 6}
# 18              5x       0.3   CCA     4  {'n_components': 6}
# 19              5x       0.3   CCA     5  {'n_components': 6}
# 20              5x         1   CCA     1  {'n_components': 6}
# 21              5x         1   CCA     2  {'n_components': 6}
# 22              5x         1   CCA     3  {'n_components': 6}
# 23              5x         1   CCA     4  {'n_components': 6}
# 24              5x         1   CCA     5  {'n_components': 6}
# 25             10x      0.01   CCA     1  {'n_components': 6}
# 26             10x      0.01   CCA     2  {'n_components': 6}
# 27             10x      0.01   CCA     3  {'n_components': 6}
# 28             10x      0.01   CCA     4  {'n_components': 6}
# 29             10x      0.01   CCA     5  {'n_components': 6}
# 30             10x       0.1   CCA     1  {'n_components': 6}
# 31             10x       0.1   CCA     2  {'n_components': 6}
# 32             10x       0.1   CCA     3  {'n_components': 6}
# 33             10x       0.1   CCA     4  {'n_components': 6}
# 34             10x       0.1   CCA     5  {'n_components': 6}
# 35             10x       0.3   CCA     1  {'n_components': 6}
# 36             10x       0.3   CCA     2  {'n_components': 6}
# 37             10x       0.3   CCA     3  {'n_components': 6}
# 38             10x       0.3   CCA     4  {'n_components': 6}
# 39             10x       0.3   CCA     5  {'n_components': 6}
# 40             10x         1   CCA     1  {'n_components': 6}
# 41             10x         1   CCA     2  {'n_components': 6}
# 42             10x         1   CCA     3  {'n_components': 6}
# 43             10x         1   CCA     4  {'n_components': 6}
# 44             10x         1   CCA     5  {'n_components': 6}

# %%
cca = pd.concat(ccalist, ignore_index=True)
bpcca = pd.concat(bpccalist, ignore_index=True)

# %%
plot_all_scores(cca, col_order=["No mixup", "5x", "10x"], hue_order=["No mixup", 0.01, 0.1, 0.3, 1.0])

# %% [markdown]
# ## 4- Multioutput Random Forest

# %%
rf = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_rf_all.h5', key='p', mode='r')
bprf = pd.read_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_rf_all.h5', key='p', mode='r')

# rf.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_multioutput_mixup_before_log_rf_all.h5', key='p', mode='w')
# bprf.to_hdf('results/multioutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_multioutput_mixup_before_log_rf_all.h5', key='p', mode='w')

# %%
rflist, bprflist = load_dfs("","*multioutput*rf*")
# Out:
# ['10x'] [0.01]
# ['10x'] [0.1]
# ['10x'] [0.3]
# ['10x'] [1.]
# ['No mixup' '5x'] ['No mixup' 0.01 0.1]
# ['5x'] [0.3 1. ]
# 6 6

# %%
bprf
# Out:
#    Data mul factor     alpha          Model  Fold  \
# 0              10x      0.01  Random Forest     1
# 1              10x      0.01  Random Forest     2
# 2              10x      0.01  Random Forest     3
# 3              10x      0.01  Random Forest     4
# 4              10x      0.01  Random Forest     5
# 5              10x       0.1  Random Forest     1
# 6              10x       0.1  Random Forest     2
# 7              10x       0.1  Random Forest     3
# 8              10x       0.1  Random Forest     4
# 9              10x       0.1  Random Forest     5
# 10             10x       0.3  Random Forest     1
# 11             10x       0.3  Random Forest     2
# 12             10x       0.3  Random Forest     3
# 13             10x       0.3  Random Forest     4
# 14             10x       0.3  Random Forest     5
# 15             10x         1  Random Forest     1
# 16             10x         1  Random Forest     2
# 17             10x         1  Random Forest     3
# 18             10x         1  Random Forest     4
# 19             10x         1  Random Forest     5
# 20        No mixup  No mixup  Random Forest     1
# 21        No mixup  No mixup  Random Forest     2
# 22        No mixup  No mixup  Random Forest     3
# 23        No mixup  No mixup  Random Forest     4
# 24        No mixup  No mixup  Random Forest     5
# 25              5x      0.01  Random Forest     1
# 26              5x      0.01  Random Forest     2
# 27              5x      0.01  Random Forest     3
# 28              5x      0.01  Random Forest     4
# 29              5x      0.01  Random Forest     5
# 30              5x       0.1  Random Forest     1
# 31              5x       0.1  Random Forest     2
# 32              5x       0.1  Random Forest     3
# 33              5x       0.1  Random Forest     4
# 34              5x       0.1  Random Forest     5
# 35              5x       0.3  Random Forest     1
# 36              5x       0.3  Random Forest     2
# 37              5x       0.3  Random Forest     3
# 38              5x       0.3  Random Forest     4
# 39              5x       0.3  Random Forest     5
# 40              5x         1  Random Forest     1
# 41              5x         1  Random Forest     2
# 42              5x         1  Random Forest     3
# 43              5x         1  Random Forest     4
# 44              5x         1  Random Forest     5
#
#                                                                                                     Best params
# 0   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 1   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 2   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 3   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 4   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 5   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 6   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 7   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 8   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 9   {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 10  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 11  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 12  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 13  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 14  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 15  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 16  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 17  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 18  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 19  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 20   {'n_estimators': 3000, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_samples': 0.5, 'max_depth': 10}
# 21   {'n_estimators': 3000, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_samples': 0.5, 'max_depth': 10}
# 22   {'n_estimators': 3000, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_samples': 0.5, 'max_depth': 10}
# 23   {'n_estimators': 3000, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_samples': 0.5, 'max_depth': 10}
# 24   {'n_estimators': 3000, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_samples': 0.5, 'max_depth': 10}
# 25  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 26  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 27  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 28  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 29  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 30  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 31  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 32  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 33  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 34  {'n_estimators': 3000, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_samples': 0.8, 'max_depth': 275}
# 35  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 36  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 37  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 38  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 39  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 40  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 41  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 42  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 43  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}
# 44  {'n_estimators': 2500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_samples': None, 'max_depth': 50}

# %%
rf = pd.concat(rflist, ignore_index=True)
bprf = pd.concat(bprflist, ignore_index=True)

# %%
plot_all_scores(rf, col_order=["No mixup", "5x", "10x"], hue_order=["No mixup", 0.01, 0.1, 0.3, 1.0])
