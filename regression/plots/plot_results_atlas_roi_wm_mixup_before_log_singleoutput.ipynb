# %%
import numpy as np
import pandas as pd
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_colwidth", 200)
pd.set_option("display.max_row", 500)

# %%
def plot_scores(score_df, metric, score_type, title="", save_folder="", col_order=None, hue_order=None):

    g = sns.catplot(x="Domain", y="Score", hue="alpha", col="Data mul factor", col_order=col_order,
                    data=score_df, ci="sd", kind="bar", hue_order=hue_order,
                    row_order=[100.0, 80.0, 60.0, 40.0, 20.0])

    g.set_axis_labels("", "Score (Mean and Standard Deviation across 5 CV folds)")

    for i, ax in enumerate(g.fig.axes):
        ax.set_xticklabels(ax.get_xticklabels(), rotation=65)
        ax.axhline(0, color="black")

    g.fig.suptitle(title, y=1.08, fontsize=30)
    
    if metric == "R2" and score_type == "Out-of-sample":
        g.set(ylim=(-1, 0.2))
#         plt.savefig(save_folder + title, bbox_inches="tight")
#         pass
        
    if metric == "R2" and (score_type == "In-sample" or score_type == "In-sample (original)"):
        g.set(ylim=(-0.05, 1.0))
        h=True
        for i, ax in enumerate(g.fig.axes):
#             if h==True:
#                 ax.axhline(0.1, color="black")
#                 ax.axhline(0.2, color="black")
#                 h=False
#             else:
            ax.axhline(0.8, color="black")
        
    if metric == "MAE":
        g.set(ylim=(0.0, 1.6))
        for i, ax in enumerate(g.fig.axes):
            ax.axhline(0.2, color="black")
        
#     plt.show()
    plt.savefig(save_folder + title, bbox_inches="tight")


def plot_all_scores(score_df, title_prefix="", save_folder="", col_order=None, hue_order=None):   

    for metric in score_df["Metric"].unique():

        for score_type in np.sort(score_df["Score type"].unique()):
            
            for model in score_df["Model"].unique():

                filtered_data = score_df[(score_df["Metric"] == metric) & (score_df["Score type"] == score_type) 
                                         & (score_df["Model"] == model)]
                
                if score_type == "In-sample (original)":
                    filtered_data = filtered_data[filtered_data["alpha"] != "No mixup"]
                    col_order_new=["5x", "10x"]
                else:
                    col_order_new = col_order

                title = title_prefix + model + " - " + metric + " - " + score_type

                plot_scores(filtered_data, metric, score_type, title, save_folder, col_order=col_order_new, hue_order=hue_order)

# %%
# utility to load results
def load_dfs(direc, regex):
    path = "/Users/hasnainmamdani/Academics/McGill/thesis/stroke-impairment-analysis/regression/mixup/results_remote/" + direc
    filenames = glob.glob(os.path.join(path, regex))
    filenames.sort()

    res = []
    bps = []
    for fn in filenames:
        if "best-params-" in fn:
            bp = pd.read_hdf(fn, key='p', mode='r')
            print(bp["% Data (train)"].unique(), bp["Data mul factor"].unique(), bp["alpha"].unique())
            bps.append(bp)
        else:
            res.append(pd.read_hdf(fn, key='p', mode='r'))

    print(len(res), len(bps))
    return res, bps

# %% [markdown]
# ## 1- Ridge

# %%
ridge = pd.read_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_singleoutput_mixup_before_log_ridge_all.h5', key='p', mode='r')
bpridge = pd.read_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_singleoutput_mixup_before_log_ridge_all.h5', key='p', mode='r')

# ridge.to_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_singleoutput_mixup_before_log_ridge_all.h5', key='p', mode='w')
# bpridge.to_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_singleoutput_mixup_before_log_ridge_all.h5', key='p', mode='w')

# %%
ridlist, bpridlist = load_dfs("", "*singleoutput*ridge*")
# Out:
# [100.] ['No mixup' '5x' '10x'] ['No mixup' 0.01 0.1]
# [100.] ['5x' '10x'] [0.3 1. ]
# 2 2

# %%
# bpridge

# %%
plot_all_scores(ridge, col_order=["No mixup", "5x", "10x"], hue_order=["No mixup", 0.01, 0.1, 0.3, 1.0])

# %% [markdown]
# ## 2- SVR - RBF

# %%
# svr = pd.read_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_singleoutput_mixup_before_log_svr_all.h5', key='p', mode='r')
# bpsvr = pd.read_hdf('results/singleoutput/atlas-with-wm-llm-mixup-before-log/best_params_atlas_llm_singleoutput_mixup_before_log_svr_all.h5', key='p', mode='r')

svr.to_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_singleoutput_mixup_before_log_svr_all.h5', key='p', mode='w')
bpsvr.to_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_singleoutput_mixup_before_log_svr_all.h5', key='p', mode='w')
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py:2368: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['Data mul factor', 'alpha', 'Model', 'Domain', 'Metric', 'Score type']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py:2368: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['Data mul factor', 'alpha', 'Model', 'Domain', 'Best params']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
svrlist, bpsvrlist = load_dfs("","*singleoutput*svr*")
# Out:
# [100.] ['No mixup' '5x'] ['No mixup' 0.01 0.1]
# [100.] ['5x'] [0.3 1. ]
# 2 2

# %%
svr = pd.concat(svrlist, ignore_index=True)
bpsvr = pd.concat(bpsvrlist, ignore_index=True)

# %%
# bpsvr

# %%
plot_all_scores(svr, col_order=["No mixup", "5x", "10x"], hue_order=["No mixup", 0.01, 0.1, 0.3, 1.0])

# %% [markdown]
# ## 3- Random Forest

# %%
rf = pd.read_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_singleoutput_mixup_before_log_rf_all.h5', key='p', mode='r')
bprf = pd.read_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_singleoutput_mixup_before_log_rf_all.h5', key='p', mode='r')

# rf.to_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/results_atlas_llm_singleoutput_mixup_before_log_rf_all.h5', key='p', mode='w')
# bprf.to_hdf('results/singleoutput/atlas-llm-with-wm-mixup-before-log/best_params_atlas_llm_singleoutput_mixup_before_log_rf_all.h5', key='p', mode='w')

# %%
rflist, bprflist = load_dfs("","*singleoutput*rf*")
# Out:
# [100.] ['No mixup' '5x' '10x'] ['No mixup' 0.01]
# [100.] ['5x' '10x'] [0.1]
# [100.] ['5x' '10x'] [0.3]
# [100.] ['5x' '10x'] [1.]
# 4 4

# %%
bprf
# Out:
#      % Data  % Data (train) Data mul factor     alpha          Model  \
# 0     100.0           100.0        No mixup  No mixup  Random Forest
# 1     100.0           100.0        No mixup  No mixup  Random Forest
# 2     100.0           100.0        No mixup  No mixup  Random Forest
# 3     100.0           100.0        No mixup  No mixup  Random Forest
# 4     100.0           100.0        No mixup  No mixup  Random Forest
# 5     100.0           100.0        No mixup  No mixup  Random Forest
# 6     100.0           100.0        No mixup  No mixup  Random Forest
# 7     100.0           100.0        No mixup  No mixup  Random Forest
# 8     100.0           100.0        No mixup  No mixup  Random Forest
# 9     100.0           100.0        No mixup  No mixup  Random Forest
# 10    100.0           100.0        No mixup  No mixup  Random Forest
# 11    100.0           100.0        No mixup  No mixup  Random Forest
# 12    100.0           100.0        No mixup  No mixup  Random Forest
# 13    100.0           100.0        No mixup  No mixup  Random Forest
# 14    100.0           100.0        No mixup  No mixup  Random Forest
# 15    100.0           100.0        No mixup  No mixup  Random Forest
# 16    100.0           100.0        No mixup  No mixup  Random Forest
# 17    100.0           100.0        No mixup  No mixup  Random Forest
# 18    100.0           100.0        No mixup  No mixup  Random Forest
# 19    100.0           100.0        No mixup  No mixup  Random Forest
# 20    100.0           100.0        No mixup  No mixup  Random Forest
# 21    100.0           100.0        No mixup  No mixup  Random Forest
# 22    100.0           100.0        No mixup  No mixup  Random Forest
# 23    100.0           100.0        No mixup  No mixup  Random Forest
# 24    100.0           100.0        No mixup  No mixup  Random Forest
# 25    100.0           100.0        No mixup  No mixup  Random Forest
# 26    100.0           100.0        No mixup  No mixup  Random Forest
# 27    100.0           100.0        No mixup  No mixup  Random Forest
# 28    100.0           100.0        No mixup  No mixup  Random Forest
# 29    100.0           100.0        No mixup  No mixup  Random Forest
# 30    100.0           100.0              5x      0.01  Random Forest
# 31    100.0           100.0              5x      0.01  Random Forest
# 32    100.0           100.0              5x      0.01  Random Forest
# 33    100.0           100.0              5x      0.01  Random Forest
# 34    100.0           100.0              5x      0.01  Random Forest
# 35    100.0           100.0              5x      0.01  Random Forest
# 36    100.0           100.0              5x      0.01  Random Forest
# 37    100.0           100.0              5x      0.01  Random Forest
# 38    100.0           100.0              5x      0.01  Random Forest
# 39    100.0           100.0              5x      0.01  Random Forest
# 40    100.0           100.0              5x      0.01  Random Forest
# 41    100.0           100.0              5x      0.01  Random Forest
# 42    100.0           100.0              5x      0.01  Random Forest
# 43    100.0           100.0              5x      0.01  Random Forest
# 44    100.0           100.0              5x      0.01  Random Forest
# 45    100.0           100.0              5x      0.01  Random Forest
# 46    100.0           100.0              5x      0.01  Random Forest
# 47    100.0           100.0              5x      0.01  Random Forest
# 48    100.0           100.0              5x      0.01  Random Forest
# 49    100.0           100.0              5x      0.01  Random Forest
# 50    100.0           100.0              5x      0.01  Random Forest
# 51    100.0           100.0              5x      0.01  Random Forest
# 52    100.0           100.0              5x      0.01  Random Forest
# 53    100.0           100.0              5x      0.01  Random Forest
# 54    100.0           100.0              5x      0.01  Random Forest
# 55    100.0           100.0              5x      0.01  Random Forest
# 56    100.0           100.0              5x      0.01  Random Forest
# 57    100.0           100.0              5x      0.01  Random Forest
# 58    100.0           100.0              5x      0.01  Random Forest
# 59    100.0           100.0              5x      0.01  Random Forest
# 60    100.0           100.0             10x      0.01  Random Forest
# 61    100.0           100.0             10x      0.01  Random Forest
# 62    100.0           100.0             10x      0.01  Random Forest
# 63    100.0           100.0             10x      0.01  Random Forest
# 64    100.0           100.0             10x      0.01  Random Forest
# 65    100.0           100.0             10x      0.01  Random Forest
# 66    100.0           100.0             10x      0.01  Random Forest
# 67    100.0           100.0             10x      0.01  Random Forest
# 68    100.0           100.0             10x      0.01  Random Forest
# 69    100.0           100.0             10x      0.01  Random Forest
# 70    100.0           100.0             10x      0.01  Random Forest
# 71    100.0           100.0             10x      0.01  Random Forest
# 72    100.0           100.0             10x      0.01  Random Forest
# 73    100.0           100.0             10x      0.01  Random Forest
# 74    100.0           100.0             10x      0.01  Random Forest
# 75    100.0           100.0             10x      0.01  Random Forest
# 76    100.0           100.0             10x      0.01  Random Forest
# 77    100.0           100.0             10x      0.01  Random Forest
# 78    100.0           100.0             10x      0.01  Random Forest
# 79    100.0           100.0             10x      0.01  Random Forest
# 80    100.0           100.0             10x      0.01  Random Forest
# 81    100.0           100.0             10x      0.01  Random Forest
# 82    100.0           100.0             10x      0.01  Random Forest
# 83    100.0           100.0             10x      0.01  Random Forest
# 84    100.0           100.0             10x      0.01  Random Forest
# 85    100.0           100.0             10x      0.01  Random Forest
# 86    100.0           100.0             10x      0.01  Random Forest
# 87    100.0           100.0             10x      0.01  Random Forest
# 88    100.0           100.0             10x      0.01  Random Forest
# 89    100.0           100.0             10x      0.01  Random Forest
# 90    100.0           100.0              5x       0.1  Random Forest
# 91    100.0           100.0              5x       0.1  Random Forest
# 92    100.0           100.0              5x       0.1  Random Forest
# 93    100.0           100.0              5x       0.1  Random Forest
# 94    100.0           100.0              5x       0.1  Random Forest
# 95    100.0           100.0              5x       0.1  Random Forest
# 96    100.0           100.0              5x       0.1  Random Forest
# 97    100.0           100.0              5x       0.1  Random Forest
# 98    100.0           100.0              5x       0.1  Random Forest
# 99    100.0           100.0              5x       0.1  Random Forest
# 100   100.0           100.0              5x       0.1  Random Forest
# 101   100.0           100.0              5x       0.1  Random Forest
# 102   100.0           100.0              5x       0.1  Random Forest
# 103   100.0           100.0              5x       0.1  Random Forest
# 104   100.0           100.0              5x       0.1  Random Forest
# 105   100.0           100.0              5x       0.1  Random Forest
# 106   100.0           100.0              5x       0.1  Random Forest
# 107   100.0           100.0              5x       0.1  Random Forest
# 108   100.0           100.0              5x       0.1  Random Forest
# 109   100.0           100.0              5x       0.1  Random Forest
# 110   100.0           100.0              5x       0.1  Random Forest
# 111   100.0           100.0              5x       0.1  Random Forest
# 112   100.0           100.0              5x       0.1  Random Forest
# 113   100.0           100.0              5x       0.1  Random Forest
# 114   100.0           100.0              5x       0.1  Random Forest
# 115   100.0           100.0              5x       0.1  Random Forest
# 116   100.0           100.0              5x       0.1  Random Forest
# 117   100.0           100.0              5x       0.1  Random Forest
# 118   100.0           100.0              5x       0.1  Random Forest
# 119   100.0           100.0              5x       0.1  Random Forest
# 120   100.0           100.0             10x       0.1  Random Forest
# 121   100.0           100.0             10x       0.1  Random Forest
# 122   100.0           100.0             10x       0.1  Random Forest
# 123   100.0           100.0             10x       0.1  Random Forest
# 124   100.0           100.0             10x       0.1  Random Forest
# 125   100.0           100.0             10x       0.1  Random Forest
# 126   100.0           100.0             10x       0.1  Random Forest
# 127   100.0           100.0             10x       0.1  Random Forest
# 128   100.0           100.0             10x       0.1  Random Forest
# 129   100.0           100.0             10x       0.1  Random Forest
# 130   100.0           100.0             10x       0.1  Random Forest
# 131   100.0           100.0             10x       0.1  Random Forest
# 132   100.0           100.0             10x       0.1  Random Forest
# 133   100.0           100.0             10x       0.1  Random Forest
# 134   100.0           100.0             10x       0.1  Random Forest
# 135   100.0           100.0             10x       0.1  Random Forest
# 136   100.0           100.0             10x       0.1  Random Forest
# 137   100.0           100.0             10x       0.1  Random Forest
# 138   100.0           100.0             10x       0.1  Random Forest
# 139   100.0           100.0             10x       0.1  Random Forest
# 140   100.0           100.0             10x       0.1  Random Forest
# 141   100.0           100.0             10x       0.1  Random Forest
# 142   100.0           100.0             10x       0.1  Random Forest
# 143   100.0           100.0             10x       0.1  Random Forest
# 144   100.0           100.0             10x       0.1  Random Forest
# 145   100.0           100.0             10x       0.1  Random Forest
# 146   100.0           100.0             10x       0.1  Random Forest
# 147   100.0           100.0             10x       0.1  Random Forest
# 148   100.0           100.0             10x       0.1  Random Forest
# 149   100.0           100.0             10x       0.1  Random Forest
# 150   100.0           100.0              5x       0.3  Random Forest
# 151   100.0           100.0              5x       0.3  Random Forest
# 152   100.0           100.0              5x       0.3  Random Forest
# 153   100.0           100.0              5x       0.3  Random Forest
# 154   100.0           100.0              5x       0.3  Random Forest
# 155   100.0           100.0              5x       0.3  Random Forest
# 156   100.0           100.0              5x       0.3  Random Forest
# 157   100.0           100.0              5x       0.3  Random Forest
# 158   100.0           100.0              5x       0.3  Random Forest
# 159   100.0           100.0              5x       0.3  Random Forest
# 160   100.0           100.0              5x       0.3  Random Forest
# 161   100.0           100.0              5x       0.3  Random Forest
# 162   100.0           100.0              5x       0.3  Random Forest
# 163   100.0           100.0              5x       0.3  Random Forest
# 164   100.0           100.0              5x       0.3  Random Forest
# 165   100.0           100.0              5x       0.3  Random Forest
# 166   100.0           100.0              5x       0.3  Random Forest
# 167   100.0           100.0              5x       0.3  Random Forest
# 168   100.0           100.0              5x       0.3  Random Forest
# 169   100.0           100.0              5x       0.3  Random Forest
# 170   100.0           100.0              5x       0.3  Random Forest
# 171   100.0           100.0              5x       0.3  Random Forest
# 172   100.0           100.0              5x       0.3  Random Forest
# 173   100.0           100.0              5x       0.3  Random Forest
# 174   100.0           100.0              5x       0.3  Random Forest
# 175   100.0           100.0              5x       0.3  Random Forest
# 176   100.0           100.0              5x       0.3  Random Forest
# 177   100.0           100.0              5x       0.3  Random Forest
# 178   100.0           100.0              5x       0.3  Random Forest
# 179   100.0           100.0              5x       0.3  Random Forest
# 180   100.0           100.0             10x       0.3  Random Forest
# 181   100.0           100.0             10x       0.3  Random Forest
# 182   100.0           100.0             10x       0.3  Random Forest
# 183   100.0           100.0             10x       0.3  Random Forest
# 184   100.0           100.0             10x       0.3  Random Forest
# 185   100.0           100.0             10x       0.3  Random Forest
# 186   100.0           100.0             10x       0.3  Random Forest
# 187   100.0           100.0             10x       0.3  Random Forest
# 188   100.0           100.0             10x       0.3  Random Forest
# 189   100.0           100.0             10x       0.3  Random Forest
# 190   100.0           100.0             10x       0.3  Random Forest
# 191   100.0           100.0             10x       0.3  Random Forest
# 192   100.0           100.0             10x       0.3  Random Forest
# 193   100.0           100.0             10x       0.3  Random Forest
# 194   100.0           100.0             10x       0.3  Random Forest
# 195   100.0           100.0             10x       0.3  Random Forest
# 196   100.0           100.0             10x       0.3  Random Forest
# 197   100.0           100.0             10x       0.3  Random Forest
# 198   100.0           100.0             10x       0.3  Random Forest
# 199   100.0           100.0             10x       0.3  Random Forest
# 200   100.0           100.0             10x       0.3  Random Forest
# 201   100.0           100.0             10x       0.3  Random Forest
# 202   100.0           100.0             10x       0.3  Random Forest
# 203   100.0           100.0             10x       0.3  Random Forest
# 204   100.0           100.0             10x       0.3  Random Forest
# 205   100.0           100.0             10x       0.3  Random Forest
# 206   100.0           100.0             10x       0.3  Random Forest
# 207   100.0           100.0             10x       0.3  Random Forest
# 208   100.0           100.0             10x       0.3  Random Forest
# 209   100.0           100.0             10x       0.3  Random Forest
# 210   100.0           100.0              5x         1  Random Forest
# 211   100.0           100.0              5x         1  Random Forest
# 212   100.0           100.0              5x         1  Random Forest
# 213   100.0           100.0              5x         1  Random Forest
# 214   100.0           100.0              5x         1  Random Forest
# 215   100.0           100.0              5x         1  Random Forest
# 216   100.0           100.0              5x         1  Random Forest
# 217   100.0           100.0              5x         1  Random Forest
# 218   100.0           100.0              5x         1  Random Forest
# 219   100.0           100.0              5x         1  Random Forest
# 220   100.0           100.0              5x         1  Random Forest
# 221   100.0           100.0              5x         1  Random Forest
# 222   100.0           100.0              5x         1  Random Forest
# 223   100.0           100.0              5x         1  Random Forest
# 224   100.0           100.0              5x         1  Random Forest
# 225   100.0           100.0              5x         1  Random Forest
# 226   100.0           100.0              5x         1  Random Forest
# 227   100.0           100.0              5x         1  Random Forest
# 228   100.0           100.0              5x         1  Random Forest
# 229   100.0           100.0              5x         1  Random Forest
# 230   100.0           100.0              5x         1  Random Forest
# 231   100.0           100.0              5x         1  Random Forest
# 232   100.0           100.0              5x         1  Random Forest
# 233   100.0           100.0              5x         1  Random Forest
# 234   100.0           100.0              5x         1  Random Forest
# 235   100.0           100.0              5x         1  Random Forest
# 236   100.0           100.0              5x         1  Random Forest
# 237   100.0           100.0              5x         1  Random Forest
# 238   100.0           100.0              5x         1  Random Forest
# 239   100.0           100.0              5x         1  Random Forest
# 240   100.0           100.0             10x         1  Random Forest
# 241   100.0           100.0             10x         1  Random Forest
# 242   100.0           100.0             10x         1  Random Forest
# 243   100.0           100.0             10x         1  Random Forest
# 244   100.0           100.0             10x         1  Random Forest
# 245   100.0           100.0             10x         1  Random Forest
# 246   100.0           100.0             10x         1  Random Forest
# 247   100.0           100.0             10x         1  Random Forest
# 248   100.0           100.0             10x         1  Random Forest
# 249   100.0           100.0             10x         1  Random Forest
# 250   100.0           100.0             10x         1  Random Forest
# 251   100.0           100.0             10x         1  Random Forest
# 252   100.0           100.0             10x         1  Random Forest
# 253   100.0           100.0             10x         1  Random Forest
# 254   100.0           100.0             10x         1  Random Forest
# 255   100.0           100.0             10x         1  Random Forest
# 256   100.0           100.0             10x         1  Random Forest
# 257   100.0           100.0             10x         1  Random Forest
# 258   100.0           100.0             10x         1  Random Forest
# 259   100.0           100.0             10x         1  Random Forest
# 260   100.0           100.0             10x         1  Random Forest
# 261   100.0           100.0             10x         1  Random Forest
# 262   100.0           100.0             10x         1  Random Forest
# 263   100.0           100.0             10x         1  Random Forest
# 264   100.0           100.0             10x         1  Random Forest
# 265   100.0           100.0             10x         1  Random Forest
# 266   100.0           100.0             10x         1  Random Forest
# 267   100.0           100.0             10x         1  Random Forest
# 268   100.0           100.0             10x         1  Random Forest
# 269   100.0           100.0             10x         1  Random Forest
#
#                            Domain  Fold  \
# 0                Global Cognition     1
# 1                Global Cognition     2
# 2                Global Cognition     3
# 3                Global Cognition     4
# 4                Global Cognition     5
# 5                        Language     1
# 6                        Language     2
# 7                        Language     3
# 8                        Language     4
# 9                        Language     5
# 10       Visuospatial Functioning     1
# 11       Visuospatial Functioning     2
# 12       Visuospatial Functioning     3
# 13       Visuospatial Functioning     4
# 14       Visuospatial Functioning     5
# 15                         Memory     1
# 16                         Memory     2
# 17                         Memory     3
# 18                         Memory     4
# 19                         Memory     5
# 20   Information Processing Speed     1
# 21   Information Processing Speed     2
# 22   Information Processing Speed     3
# 23   Information Processing Speed     4
# 24   Information Processing Speed     5
# 25          Executive Functioning     1
# 26          Executive Functioning     2
# 27          Executive Functioning     3
# 28          Executive Functioning     4
# 29          Executive Functioning     5
# 30               Global Cognition     1
# 31               Global Cognition     2
# 32               Global Cognition     3
# 33               Global Cognition     4
# 34               Global Cognition     5
# 35                       Language     1
# 36                       Language     2
# 37                       Language     3
# 38                       Language     4
# 39                       Language     5
# 40       Visuospatial Functioning     1
# 41       Visuospatial Functioning     2
# 42       Visuospatial Functioning     3
# 43       Visuospatial Functioning     4
# 44       Visuospatial Functioning     5
# 45                         Memory     1
# 46                         Memory     2
# 47                         Memory     3
# 48                         Memory     4
# 49                         Memory     5
# 50   Information Processing Speed     1
# 51   Information Processing Speed     2
# 52   Information Processing Speed     3
# 53   Information Processing Speed     4
# 54   Information Processing Speed     5
# 55          Executive Functioning     1
# 56          Executive Functioning     2
# 57          Executive Functioning     3
# 58          Executive Functioning     4
# 59          Executive Functioning     5
# 60               Global Cognition     1
# 61               Global Cognition     2
# 62               Global Cognition     3
# 63               Global Cognition     4
# 64               Global Cognition     5
# 65                       Language     1
# 66                       Language     2
# 67                       Language     3
# 68                       Language     4
# 69                       Language     5
# 70       Visuospatial Functioning     1
# 71       Visuospatial Functioning     2
# 72       Visuospatial Functioning     3
# 73       Visuospatial Functioning     4
# 74       Visuospatial Functioning     5
# 75                         Memory     1
# 76                         Memory     2
# 77                         Memory     3
# 78                         Memory     4
# 79                         Memory     5
# 80   Information Processing Speed     1
# 81   Information Processing Speed     2
# 82   Information Processing Speed     3
# 83   Information Processing Speed     4
# 84   Information Processing Speed     5
# 85          Executive Functioning     1
# 86          Executive Functioning     2
# 87          Executive Functioning     3
# 88          Executive Functioning     4
# 89          Executive Functioning     5
# 90               Global Cognition     1
# 91               Global Cognition     2
# 92               Global Cognition     3
# 93               Global Cognition     4
# 94               Global Cognition     5
# 95                       Language     1
# 96                       Language     2
# 97                       Language     3
# 98                       Language     4
# 99                       Language     5
# 100      Visuospatial Functioning     1
# 101      Visuospatial Functioning     2
# 102      Visuospatial Functioning     3
# 103      Visuospatial Functioning     4
# 104      Visuospatial Functioning     5
# 105                        Memory     1
# 106                        Memory     2
# 107                        Memory     3
# 108                        Memory     4
# 109                        Memory     5
# 110  Information Processing Speed     1
# 111  Information Processing Speed     2
# 112  Information Processing Speed     3
# 113  Information Processing Speed     4
# 114  Information Processing Speed     5
# 115         Executive Functioning     1
# 116         Executive Functioning     2
# 117         Executive Functioning     3
# 118         Executive Functioning     4
# 119         Executive Functioning     5
# 120              Global Cognition     1
# 121              Global Cognition     2
# 122              Global Cognition     3
# 123              Global Cognition     4
# 124              Global Cognition     5
# 125                      Language     1
# 126                      Language     2
# 127                      Language     3
# 128                      Language     4
# 129                      Language     5
# 130      Visuospatial Functioning     1
# 131      Visuospatial Functioning     2
# 132      Visuospatial Functioning     3
# 133      Visuospatial Functioning     4
# 134      Visuospatial Functioning     5
# 135                        Memory     1
# 136                        Memory     2
# 137                        Memory     3
# 138                        Memory     4
# 139                        Memory     5
# 140  Information Processing Speed     1
# 141  Information Processing Speed     2
# 142  Information Processing Speed     3
# 143  Information Processing Speed     4
# 144  Information Processing Speed     5
# 145         Executive Functioning     1
# 146         Executive Functioning     2
# 147         Executive Functioning     3
# 148         Executive Functioning     4
# 149         Executive Functioning     5
# 150              Global Cognition     1
# 151              Global Cognition     2
# 152              Global Cognition     3
# 153              Global Cognition     4
# 154              Global Cognition     5
# 155                      Language     1
# 156                      Language     2
# 157                      Language     3
# 158                      Language     4
# 159                      Language     5
# 160      Visuospatial Functioning     1
# 161      Visuospatial Functioning     2
# 162      Visuospatial Functioning     3
# 163      Visuospatial Functioning     4
# 164      Visuospatial Functioning     5
# 165                        Memory     1
# 166                        Memory     2
# 167                        Memory     3
# 168                        Memory     4
# 169                        Memory     5
# 170  Information Processing Speed     1
# 171  Information Processing Speed     2
# 172  Information Processing Speed     3
# 173  Information Processing Speed     4
# 174  Information Processing Speed     5
# 175         Executive Functioning     1
# 176         Executive Functioning     2
# 177         Executive Functioning     3
# 178         Executive Functioning     4
# 179         Executive Functioning     5
# 180              Global Cognition     1
# 181              Global Cognition     2
# 182              Global Cognition     3
# 183              Global Cognition     4
# 184              Global Cognition     5
# 185                      Language     1
# 186                      Language     2
# 187                      Language     3
# 188                      Language     4
# 189                      Language     5
# 190      Visuospatial Functioning     1
# 191      Visuospatial Functioning     2
# 192      Visuospatial Functioning     3
# 193      Visuospatial Functioning     4
# 194      Visuospatial Functioning     5
# 195                        Memory     1
# 196                        Memory     2
# 197                        Memory     3
# 198                        Memory     4
# 199                        Memory     5
# 200  Information Processing Speed     1
# 201  Information Processing Speed     2
# 202  Information Processing Speed     3
# 203  Information Processing Speed     4
# 204  Information Processing Speed     5
# 205         Executive Functioning     1
# 206         Executive Functioning     2
# 207         Executive Functioning     3
# 208         Executive Functioning     4
# 209         Executive Functioning     5
# 210              Global Cognition     1
# 211              Global Cognition     2
# 212              Global Cognition     3
# 213              Global Cognition     4
# 214              Global Cognition     5
# 215                      Language     1
# 216                      Language     2
# 217                      Language     3
# 218                      Language     4
# 219                      Language     5
# 220      Visuospatial Functioning     1
# 221      Visuospatial Functioning     2
# 222      Visuospatial Functioning     3
# 223      Visuospatial Functioning     4
# 224      Visuospatial Functioning     5
# 225                        Memory     1
# 226                        Memory     2
# 227                        Memory     3
# 228                        Memory     4
# 229                        Memory     5
# 230  Information Processing Speed     1
# 231  Information Processing Speed     2
# 232  Information Processing Speed     3
# 233  Information Processing Speed     4
# 234  Information Processing Speed     5
# 235         Executive Functioning     1
# 236         Executive Functioning     2
# 237         Executive Functioning     3
# 238         Executive Functioning     4
# 239         Executive Functioning     5
# 240              Global Cognition     1
# 241              Global Cognition     2
# 242              Global Cognition     3
# 243              Global Cognition     4
# 244              Global Cognition     5
# 245                      Language     1
# 246                      Language     2
# 247                      Language     3
# 248                      Language     4
# 249                      Language     5
# 250      Visuospatial Functioning     1
# 251      Visuospatial Functioning     2
# 252      Visuospatial Functioning     3
# 253      Visuospatial Functioning     4
# 254      Visuospatial Functioning     5
# 255                        Memory     1
# 256                        Memory     2
# 257                        Memory     3
# 258                        Memory     4
# 259                        Memory     5
# 260  Information Processing Speed     1
# 261  Information Processing Speed     2
# 262  Information Processing Speed     3
# 263  Information Processing Speed     4
# 264  Information Processing Speed     5
# 265         Executive Functioning     1
# 266         Executive Functioning     2
# 267         Executive Functioning     3
# 268         Executive Functioning     4
# 269         Executive Functioning     5
#
#                                                                                                                                Best params
# 0     {'n_estimators': 1750, 'min_samples_split': 70, 'min_samples_leaf': 12, 'max_samples': 0.25, 'max_features': 'auto', 'max_depth': 5}
# 1     {'n_estimators': 3500, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_samples': 0.25, 'max_features': 'sqrt', 'max_depth': 10}
# 2     {'n_estimators': 3500, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_samples': 0.25, 'max_features': 'sqrt', 'max_depth': 10}
# 3      {'n_estimators': 1250, 'min_samples_split': 25, 'min_samples_leaf': 4, 'max_samples': 0.5, 'max_features': 'auto', 'max_depth': 70}
# 4    {'n_estimators': 250, 'min_samples_split': 90, 'min_samples_leaf': 2, 'max_samples': None, 'max_features': 'sqrt', 'max_depth': None}
# 5      {'n_estimators': 750, 'min_samples_split': 50, 'min_samples_leaf': 1, 'max_samples': 0.1, 'max_features': 'auto', 'max_depth': 100}
# 6     {'n_estimators': 3500, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_samples': 0.25, 'max_features': 'sqrt', 'max_depth': 10}
# 7     {'n_estimators': 1750, 'min_samples_split': 70, 'min_samples_leaf': 12, 'max_samples': 0.25, 'max_features': 'auto', 'max_depth': 5}
# 8     {'n_estimators': 1750, 'min_samples_split': 70, 'min_samples_leaf': 12, 'max_samples': 0.25, 'max_features': 'auto', 'max_depth': 5}
# 9      {'n_estimators': 750, 'min_samples_split': 50, 'min_samples_leaf': 1, 'max_samples': 0.1, 'max_features': 'auto', 'max_depth': 100}
# 10     {'n_estimators': 100, 'min_samples_split': 40, 'min_samples_leaf': 21, 'max_samples': 0.4, 'max_features': 'auto', 'max_depth': 20}
# 11       {'n_estimators': 200, 'min_samples_split': 30, 'min_samples_leaf': 4, 'max_samples': 0.2, 'max_features': 'sqrt', 'max_depth': 5}
# 12    {'n_estimators': 2000, 'min_samples_split': 15, 'min_samples_leaf': 24, 'max_samples': 0.5, 'max_features': 'auto', 'max_depth': 15}
# 13      {'n_estimators': 50, 'min_samples_split': 40, 'min_samples_leaf': 15, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 40}
# 14    {'n_estimators': 2000, 'min_samples_split': 15, 'min_samples_leaf': 24, 'max_samples': 0.5, 'max_features': 'auto', 'max_depth': 15}
# 15     {'n_estimators': 750, 'min_samples_split': 50, 'min_samples_leaf': 1, 'max_samples': 0.1, 'max_features': 'auto', 'max_depth': 100}
# 16    {'n_estimators': 3500, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_samples': 0.25, 'max_features': 'sqrt', 'max_depth': 10}
# 17     {'n_estimators': 250, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_samples': 0.8, 'max_features': 'sqrt', 'max_depth': 50}
# 18     {'n_estimators': 250, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_samples': 0.8, 'max_features': 'sqrt', 'max_depth': 50}
# 19     {'n_estimators': 750, 'min_samples_split': 50, 'min_samples_leaf': 1, 'max_samples': 0.1, 'max_features': 'auto', 'max_depth': 100}
# 20     {'n_estimators': 500, 'min_samples_split': 80, 'min_samples_leaf': 21, 'max_samples': 0.3, 'max_features': 'sqrt', 'max_depth': 90}
# 21    {'n_estimators': 2500, 'min_samples_split': 25, 'min_samples_leaf': 21, 'max_samples': 0.3, 'max_features': 'sqrt', 'max_depth': 20}
# 22     {'n_estimators': 500, 'min_samples_split': 80, 'min_samples_leaf': 21, 'max_samples': 0.3, 'max_features': 'sqrt', 'max_depth': 90}
# 23     {'n_estimators': 3500, 'min_samples_split': 2, 'min_samples_leaf': 21, 'max_samples': 0.2, 'max_features': 'auto', 'max_depth': 40}
# 24    {'n_estimators': 2500, 'min_samples_split': 25, 'min_samples_leaf': 21, 'max_samples': 0.3, 'max_features': 'sqrt', 'max_depth': 20}
# 25     {'n_estimators': 500, 'min_samples_split': 80, 'min_samples_leaf': 21, 'max_samples': 0.3, 'max_features': 'sqrt', 'max_depth': 90}
# 26     {'n_estimators': 3500, 'min_samples_split': 2, 'min_samples_leaf': 21, 'max_samples': 0.2, 'max_features': 'auto', 'max_depth': 40}
# 27    {'n_estimators': 2500, 'min_samples_split': 25, 'min_samples_leaf': 21, 'max_samples': 0.3, 'max_features': 'sqrt', 'max_depth': 20}
# 28    {'n_estimators': 2500, 'min_samples_split': 25, 'min_samples_leaf': 21, 'max_samples': 0.3, 'max_features': 'sqrt', 'max_depth': 20}
# 29     {'n_estimators': 3500, 'min_samples_split': 2, 'min_samples_leaf': 21, 'max_samples': 0.2, 'max_features': 'auto', 'max_depth': 40}
# 30      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 31      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 32      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 33      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 34      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 35      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 36      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 37      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 38      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 39      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 40      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 41      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 42      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 43      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 44      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 45      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 46      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 47      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 48      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 49      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 50      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 51      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 52      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 53      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 54      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 55      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 56      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 57      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 58      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 59      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 60      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 61      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 62      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 63      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 64      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 65      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 66      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 67      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 68      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 69      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 70      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 71      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 72      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 73      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 74      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 75      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 76      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 77      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 78      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 79      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 80      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 81      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 82      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 83      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 84      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 85      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 86      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 87      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 88      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 89      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 90      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 91      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 92      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 93      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 94      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 95      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 96      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 97      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 98      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 99      {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 100     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 101     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 102     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 103     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 104     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 105     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 106     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 107     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 108     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 109     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 110     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 111     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 112     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 113     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 114     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 115     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 116     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 117     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# ...
# 157     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 158     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 159     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 160     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 161     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 162     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 163     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 164     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 165     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 166     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 167     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 168     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 169     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 170     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 171     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 172     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 173     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 174     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 175     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 176     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 177     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 178     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 179     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 180     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 181     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 182     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 183     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 184     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 185     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 186     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 187     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 188     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 189     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 190     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 191     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 192     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 193     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 194     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 195     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 196     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 197     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 198     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 199     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 200     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 201     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 202     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 203     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 204     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 205     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 206     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 207     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 208     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 209     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 210     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 211     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 212     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 213     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 214     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 215     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 216     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 217     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 218     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 219     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 220     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 221     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 222     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 223     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 224     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 225     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 226     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 227     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 228     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 229     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 230     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 231     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 232     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 233     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 234     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 235     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 236     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 237     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 238     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 239     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 240     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 241     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 242     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 243     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 244     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 245     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 246     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 247     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 248     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 249     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 250     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 251     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 252     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 253     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 254     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 255     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 256     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 257     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 258     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 259     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 260     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 261     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 262     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 263     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 264     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 265     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 266     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 267     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 268     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}
# 269     {'n_estimators': 1250, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_samples': 0.8, 'max_features': 'auto', 'max_depth': 70}

# %%
rf = pd.concat(rflist, ignore_index=True)
bprf = pd.concat(bprflist, ignore_index=True)

# %%
plot_all_scores(rf, col_order=["No mixup", "5x", "10x"], hue_order=["No mixup", 0.01, 0.1, 0.3, 1.0])
